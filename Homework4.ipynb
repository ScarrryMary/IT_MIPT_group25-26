# %% [markdown]
# <a href="https://colab.research.google.com/github/ScarrryMary/IT_MIPT_group25-26/blob/main/Homework4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание №4

# %% [markdown]
# ### Упражнение 4.1 (Эксперименты)
#
# Составьте произвольный набор данных (например, внесите данные с лабораторной работы). Постройте на них график, подходящий для отчета по общей физике.

# %% [markdown]
# ### Упражнение 4.2 (Стремление к нормальности)
#
# Постройте на одном рисунке (но разных подграфиках) несколько (>2) гистограмм, которые покажут, что с увеличением количества точек, полученных из нормального распределения, гистограмма значений этих точек стремится к нормальному распределению.
# Должно получиться что-то такое:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 4.3 (Пироги с цветами)
# Постройте из файла `iris_data.csv` -- стандартного датасета цветков ириса -- две круговые диаграммы: доля разных видов (Species) ирисов в датасете, доли ирисов, у которых длина лепестка (PetalLengthCm) больше 1.2см, больше 1.2см и меньше 1.5см, больше 1.5см.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных
df = pd.read_csv('iris_data.csv')

# Создание фигуры с двумя подграфиками
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7))

# Первая круговая диаграмма: распределение по видам ирисов
species_counts = df['Species'].value_counts()
...

# Вторая круговая диаграмма: распределение по длине лепестка
petal_length = df['PetalLengthCm']
...

# %% [markdown]
# Пример того, что должно получиться:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение №4.7 (Буквоед)***
#
# Дан текст на некотором языке. Требуется подсчитать сколько раз каждое
# слово входит в этот текст и вывести десять самых часто употребяемых слов
# в этом тексте и количество их употреблений.
#
# В качестве примера возьмите файл с текстом лицензионного соглашения
# Python `/usr/share/licenses/python/LICENSE`.
#
# Подсказка №1: Используйте словарь, в котором ключ \-- слово, а значение
# \-- количество таких слов.
#
# Подсказка №2: Точки, запятые, вопросы и восклицательные знаки перед
# обработкой замените пробелами (используйте [punctuation](https://docs.python.org/2/library/string.html#string.punctuation)
# из модуля string).
#
# Подсказка №3: Все слова приводите к нижнему регистру при помощи метода
# строки `lower()`.
#
# Подсказка №4: По окончании сбора статистики нужно пробежать по всем
# ключам из словаря и найти ключ с максимальным значением.

# %%
import string

# Создаем таблицу перевода
translator = str.maketrans('', '', string.punctuation)

# Пример текста
text = "Hello, world! How are you? I'm fine, thanks."
cleaned_text = text.translate(translator)

print("Исходный текст:", text)
print("Очищенный текст:", cleaned_text)
# Out:
# Исходный текст: Hello, world! How are you? I'm fine, thanks.
# Очищенный текст: Hello world How are you Im fine thanks

# %%
import string

def count_words_with_max(filename):
    # Чтение файла
    with open(filename, 'r', encoding='utf-8') as file:
            text = file.read()

    # Подготовка текста
    translator = str.maketrans('', '', string.punctuation)
    cleaned_text = text.translate(translator).lower()

    # Разделение на слова
    # Подсчет слов вручную
    # Получение топ-10 через поиск максимумов


filename = "/usr/share/licenses/python/LICENSE"

print("=" * 50)
print("САМЫЕ ЧАСТОТНЫЕ СЛОВА В ЛИЦЕНЗИИ PYTHON")
print("=" * 50)

# %% [markdown]
# ### Упражнение №4.8 (Счетовод)
#
# Задайте два списка чисел. Выведите числа:
# * Уникальные для каждого списка
# * Уникальные для объединения этих списков
# * Содержащиеся в обоих списках
# используя множества и логические операции с ними.
